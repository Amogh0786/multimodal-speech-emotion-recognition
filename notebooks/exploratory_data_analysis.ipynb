# %% [markdown]
# # Exploratory Data Analysis for RAVDESS Dataset
#
# This notebook will help visualize the waveforms, spectrograms, and perform basic statistics on the RAVDESS dataset.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path

# Create dataset folds using existing function
import sys
sys.path.append('../')
from src.data.dataset import create_folds

df = create_folds('../data/raw')
df.head()

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='label')
plt.title('Distribution of Emotion Labels')
plt.xlabel('Emotion (0=Calm, 1=Happy, 2=Angry, 3=Stressed)')
plt.ylabel('Count')
plt.show()
